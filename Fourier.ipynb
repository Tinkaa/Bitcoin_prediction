# %%
import numpy as np
import pandas as pd
import seaborn
from matplotlib import pyplot as plt

# %%
DF = pd.read_csv("bitcoin_start-240418.csv")
DF = DF[:-2]
prices = np.array(DF["Close Price"])

# %%
prices
# Out:
# array([9.00000e-02, 8.00000e-02, 7.00000e-02, ..., 8.79283e+03,
#        8.93830e+03, 9.29046e+03])

# %%
# Nyquist Sampling
N = prices.size
T = 1/(N) # inverse of the sampling rate
x = np.linspace(0.0, 1.0/(2.0*T), int(N/2))

fft = np.fft.rfft(prices)
pwr = np.abs(fft)  # AMPLITUDE
pwr = 2/N * np.abs(pwr[0:np.int(N/2)]) # positive freqs only

#timestep = 1 / fft.size
#freq = np.fft.fftfreq(fft.size, timestep)

plt.plot(x, pwr)
plt.ylabel("Power")
plt.xlabel("Frequency Hz")
plt.title("Power spectral of Bitcoin price")
plt.xlim((0, 40))

plt.show()

# %%
toy = np.zeros(35)
toy[6] = pwr[6]
inverse = np.fft.ifft(toy)

# %%
frame = np.linspace(0, len(toy)-1, len(toy))

plt.plot(frame, inverse)
plt.show()
# Out:
# /m/home/home2/27/holopaj7/unix/Envs/GaussianProcesses/lib/python3.5/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
print(inverse[0])
# Out:
# (27.520777311637723+0j)
